# %%
import os
import pandas as pd

# %%
# Function to combine joint data files for each subject and format column headings
def combine_joint_data_for_subjects(base_dir):
    # List all subject directories
    subjects = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]
    
    for subject in subjects:
        subject_dir = os.path.join(base_dir, subject)
        combined_df = pd.DataFrame()
        
        # List all joint files within the subject directory
        joint_files = [f for f in os.listdir(subject_dir) if f.endswith('.csv')]
        
        for joint_file in joint_files:
            joint_name = joint_file.split('.')[0]  # Extract joint name from file name
            file_path = os.path.join(subject_dir, joint_file)
            
            # Read the CSV file with explicit delimiter
            df = pd.read_csv(file_path, delimiter=',')
            
            if 'Time (s)' in df.columns[0]:
                # Split columns if they are not correctly split
                df = df[df.columns[0]].str.split(',', expand=True)
                df.columns = ['Time (s)', 'X (m/s2)', 'Y (m/s2)', 'Z (m/s2)', 'R (m/s2)', 'Theta (deg)', 'Phi (deg)']
            
            # Drop the "Time (s)" column
            df = df.drop(columns=['Time (s)'])
            
            # Rename columns to include the joint name
            df.columns = [f"{col}_{joint_name}" for col in df.columns]
            
            # Debugging prints
            print(f"Processing {file_path}")
            print(f"Renamed columns: {df.columns}")
            
            # Concatenate horizontally
            if combined_df.empty:
                combined_df = df
            else:
                combined_df = pd.concat([combined_df, df], axis=1)
        
        # Save the combined DataFrame to a CSV file
        combined_csv_path = os.path.join(base_dir, f'{subject}_combined_joint_data.csv')
        combined_df.to_csv(combined_csv_path, index=False)
        print(f"CSV file for {subject} created successfully.")

# %%
# Define the base directory where the subject folders are located
base_directory = 'Final_Dataset'  # Replace with the actual path to your base directory

# Combine joint data for each subject
combine_joint_data_for_subjects(base_directory)
# Out:
# Processing Final_Dataset/Abhay/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Abhay/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Abhay/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Abhay/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Abhay/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Abhay/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Abhay created successfully.
# Processing Final_Dataset/Kavya/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Kavya/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Kavya/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Kavya/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Kavya/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Kavya/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Kavya created successfully.
# Processing Final_Dataset/Gaavya/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Gaavya/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Gaavya/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Gaavya/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Gaavya/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Gaavya/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Gaavya created successfully.
# Processing Final_Dataset/Vishnu/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Vishnu/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Vishnu/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Vishnu/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Vishnu/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Vishnu/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Vishnu created successfully.
# Processing Final_Dataset/Vinayak/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Vinayak/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Vinayak/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Vinayak/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Vinayak/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Vinayak/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Vinayak created successfully.
# Processing Final_Dataset/Ragesh/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Ragesh/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Ragesh/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Ragesh/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Ragesh/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Ragesh/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Ragesh created successfully.
# Processing Final_Dataset/Krishnanand/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Krishnanand/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Krishnanand/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Krishnanand/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Krishnanand/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Krishnanand/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Krishnanand created successfully.
# Processing Final_Dataset/Me/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Me/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Me/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Me/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Me/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Me/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Me created successfully.
# Processing Final_Dataset/Ashna/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/Ashna/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/Ashna/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/Ashna/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/Ashna/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/Ashna/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for Ashna created successfully.
# Processing Final_Dataset/SreeMegha/LK.csv
# Renamed columns: Index(['X (m/s2)_LK', 'Y (m/s2)_LK', 'Z (m/s2)_LK', 'R (m/s2)_LK',
#        'Theta (deg)_LK', 'Phi (deg)_LK'],
#       dtype='object')
# Processing Final_Dataset/SreeMegha/LH.csv
# Renamed columns: Index(['X (m/s2)_LH', 'Y (m/s2)_LH', 'Z (m/s2)_LH', 'R (m/s2)_LH',
#        'Theta (deg)_LH', 'Phi (deg)_LH'],
#       dtype='object')
# Processing Final_Dataset/SreeMegha/RH.csv
# Renamed columns: Index(['X (m/s2)_RH', 'Y (m/s2)_RH', 'Z (m/s2)_RH', 'R (m/s2)_RH',
#        'Theta (deg)_RH', 'Phi (deg)_RH'],
#       dtype='object')
# Processing Final_Dataset/SreeMegha/RK.csv
# Renamed columns: Index(['X (m/s2)_RK', 'Y (m/s2)_RK', 'Z (m/s2)_RK', 'R (m/s2)_RK',
#        'Theta (deg)_RK', 'Phi (deg)_RK'],
#       dtype='object')
# Processing Final_Dataset/SreeMegha/RA.csv
# Renamed columns: Index(['X (m/s2)_RA', 'Y (m/s2)_RA', 'Z (m/s2)_RA', 'R (m/s2)_RA',
#        'Theta (deg)_RA', 'Phi (deg)_RA'],
#       dtype='object')
# Processing Final_Dataset/SreeMegha/LA.csv
# Renamed columns: Index(['X (m/s2)_LA', 'Y (m/s2)_LA', 'Z (m/s2)_LA', 'R (m/s2)_LA',
#        'Theta (deg)_LA', 'Phi (deg)_LA'],
#       dtype='object')
# CSV file for SreeMegha created successfully.
