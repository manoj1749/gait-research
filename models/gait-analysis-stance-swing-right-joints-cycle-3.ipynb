# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
def process_gait_data(file_path):
    scaler = MinMaxScaler()
    df = pd.read_csv(file_path)    
    if 'Time (s)' in df.columns:
        df.drop(columns=['Time (s)'], inplace=True)        
    df = df.ffill().bfill()  
    df.replace([np.inf, -np.inf], np.nan, inplace=True) 
    df.dropna(inplace=True) 
    data_scaled = scaler.fit_transform(df)    
    min_val, max_val = np.min(data_scaled), np.max(data_scaled)
    print("Min value:", min_val, "Max value:", max_val)    
    df_scaled = pd.DataFrame(data_scaled, columns=df.columns)
    return df_scaled, scaler

# %%
stance_RA = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Stance/RA.csv'
stance_RH = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Stance/RH.csv'
stance_RK = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Stance/RK.csv'
swing_RA = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Swing/RA.csv'
swing_RH = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Swing/RH.csv'
swing_RK = '/kaggle/input/stance-swing-dataset/Processed/subject-1/trail-1/cycle-3/Right Swing/RK.csv'

scaled_stance_RA, scaler_stance_RA = process_gait_data(stance_RA)
scaled_stance_RH, scaler_stance_RH = process_gait_data(stance_RH)
scaled_stance_RK, scaler_stance_RK = process_gait_data(stance_RK)
scaled_swing_RA, scaler_swing_RA = process_gait_data(swing_RA)
scaled_swing_RH, scaler_swing_RH = process_gait_data(swing_RH)
scaled_swing_RK, scaler_swing_RK = process_gait_data(swing_RK)

print(scaled_stance_RA.head())
# Out:
# Min value: 0.0 Max value: 1.0
# Min value: 0.0 Max value: 1.0
# Min value: 0.0 Max value: 1.0000000000000002
# Min value: 0.0 Max value: 1.0
# Min value: 0.0 Max value: 1.0000000000000002
# Min value: 0.0 Max value: 1.0
#    X (m/s^2)  Y (m/s^2)  Z (m/s^2)     Theta
# 0   0.898739   0.645752   0.220722  0.747095
# 1   0.797477   0.571000   0.160832  0.813209
# 2   0.798879   0.663164   0.206149  0.758476
# 3   0.816924   0.726208   0.293229  0.669308
# 4   0.846531   0.609126   0.253243  0.718509

# %%
def create_sequences(data, seq_length):
    data = np.array(data)
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append((seq, target))
    return sequences

seq_length = 10

sequences_ST_RA = create_sequences(scaled_stance_RA, seq_length)
sequences_ST_RH = create_sequences(scaled_stance_RH, seq_length)
sequences_ST_RK = create_sequences(scaled_stance_RK, seq_length)
sequences_SW_RA = create_sequences(scaled_swing_RA, seq_length)
sequences_SW_RH = create_sequences(scaled_swing_RH, seq_length)
sequences_SW_RK = create_sequences(scaled_swing_RK, seq_length)

# %%
def extract_X_y(sequences):
    X = np.array([seq[0] for seq in sequences])
    y = np.array([seq[1] for seq in sequences])
    return X, y

X_ST_RA, y_ST_RA = extract_X_y(sequences_ST_RA)
X_ST_RH, y_ST_RH = extract_X_y(sequences_ST_RH)
X_ST_RK, y_ST_RK = extract_X_y(sequences_ST_RK)
X_SW_RA, y_SW_RA = extract_X_y(sequences_SW_RA)
X_SW_RH, y_SW_RH = extract_X_y(sequences_SW_RH)
X_SW_RK, y_SW_RK = extract_X_y(sequences_SW_RK)

print(f"X_ST_RA shape: {X_ST_RA.shape}, y_ST_RA shape: {y_ST_RA.shape}")
print(np.isnan(X_ST_RA).sum(), np.isnan(y_ST_RA).sum())  
print(np.isinf(X_ST_RA).sum(), np.isinf(y_ST_RA).sum()) 

print(f"X_ST_RH shape: {X_ST_RH.shape}, y_ST_RH shape: {y_ST_RH.shape}")
print(np.isnan(X_ST_RH).sum(), np.isnan(y_ST_RH).sum()) 
print(np.isinf(X_ST_RH).sum(), np.isinf(y_ST_RH).sum()) 

print(f"X_ST_RK shape: {X_ST_RK.shape}, y_ST_RK shape: {y_ST_RK.shape}")
print(np.isnan(X_ST_RK).sum(), np.isnan(y_ST_RK).sum()) 
print(np.isinf(X_ST_RK).sum(), np.isinf(y_ST_RK).sum())  

print(f"X_SW_RA shape: {X_SW_RA.shape}, y_SW_RA shape: {y_SW_RA.shape}")
print(np.isnan(X_SW_RA).sum(), np.isnan(y_SW_RA).sum()) 
print(np.isinf(X_SW_RA).sum(), np.isinf(y_SW_RA).sum())  

print(f"X_SW_RH shape: {X_SW_RH.shape}, y_SW_RH shape: {y_SW_RH.shape}")
print(np.isnan(X_SW_RH).sum(), np.isnan(y_SW_RH).sum())  
print(np.isinf(X_SW_RH).sum(), np.isinf(y_SW_RH).sum()) 

print(f"X_SW_RK shape: {X_SW_RK.shape}, y_SW_RK shape: {y_SW_RK.shape}")
print(np.isnan(X_SW_RK).sum(), np.isnan(y_SW_RK).sum())  
print(np.isinf(X_SW_RK).sum(), np.isinf(y_SW_RK).sum())
# Out:
# X_ST_RA shape: (91, 10, 4), y_ST_RA shape: (91, 4)
# 0 0
# 0 0
# X_ST_RH shape: (192, 10, 4), y_ST_RH shape: (192, 4)
# 0 0
# 0 0
# X_ST_RK shape: (91, 10, 4), y_ST_RK shape: (91, 4)
# 0 0
# 0 0
# X_SW_RA shape: (91, 10, 4), y_SW_RA shape: (91, 4)
# 0 0
# 0 0
# X_SW_RH shape: (192, 10, 4), y_SW_RH shape: (192, 4)
# 0 0
# 0 0
# X_SW_RK shape: (88, 10, 4), y_SW_RK shape: (88, 4)
# 0 0
# 0 0

# %%
def split_train_test(X, y, train_size=0.8):
    split_index = int(len(X) * train_size)
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    return X_train, X_test, y_train, y_test

X_train_ST_RA, X_test_ST_RA, y_train_ST_RA, y_test_ST_RA = split_train_test(X_ST_RA, y_ST_RA)
X_train_ST_RH, X_test_ST_RH, y_train_ST_RH, y_test_ST_RH = split_train_test(X_ST_RH, y_ST_RH)
X_train_ST_RK, X_test_ST_RK, y_train_ST_RK, y_test_ST_RK = split_train_test(X_ST_RK, y_ST_RK)
X_train_SW_RA, X_test_SW_RA, y_train_SW_RA, y_test_SW_RA = split_train_test(X_SW_RA, y_SW_RA)
X_train_SW_RH, X_test_SW_RH, y_train_SW_RH, y_test_SW_RH = split_train_test(X_SW_RH, y_SW_RH)
X_train_SW_RK, X_test_SW_RK, y_train_SW_RK, y_test_SW_RK = split_train_test(X_SW_RK, y_SW_RK)

# %%
# Print shapes of the training sets
print(X_train_ST_RA.shape)
print(X_train_ST_RH.shape)
print(X_train_ST_RK.shape)
print(X_train_SW_RA.shape)
print(X_train_SW_RH.shape)
print(X_train_SW_RK.shape)
# Out:
# (72, 10, 4)
# (153, 10, 4)
# (72, 10, 4)
# (72, 10, 4)
# (153, 10, 4)
# (70, 10, 4)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam

# %%
# GRU model
def create_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(50, activation='tanh', return_sequences=True, input_shape=input_shape))
    model.add(GRU(50, activation='tanh'))
    model.add(Dense(input_shape[-1]))
    model.compile(optimizer=Adam(learning_rate=0.001, clipnorm=1.0), loss='mse')
    return model

# %%
# # Prepare input shape
# input_shape = (X_train_LK.shape[1], X_train_LK.shape[2])

# gru_model = create_gru_model(input_shape)
# gru_model.summary()

# %%
def train_gru_for_joint(X_train, y_train, joint_name):
    input_shape = (X_train.shape[1], X_train.shape[2])
    gru_model = create_gru_model(input_shape)
    print(f"Training GRU model for {joint_name}...")
    gru_model.summary()
    history = gru_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
    return history, gru_model

# %%
histories = {}
models = {}

joint_data = {
    'ST_RA': (X_train_ST_RA, y_train_ST_RA),
    'ST_RH': (X_train_ST_RH, y_train_ST_RH),
    'ST_RK': (X_train_ST_RK, y_train_ST_RK),
    'SW_RA': (X_train_SW_RA, y_train_SW_RA),
    'SW_RH': (X_train_SW_RH, y_train_SW_RH),
    'SW_RK': (X_train_SW_RK, y_train_SW_RK)
}

# %%
for joint, (X_train, y_train) in joint_data.items():
    history, model = train_gru_for_joint(X_train, y_train, joint)
    histories[joint] = history
    models[joint] = model

print(histories)
print(models)
# Out:
# Training GRU model for ST_RA...
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 614ms/step - loss: 0.4151 - val_loss: 0.2842
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2733 - val_loss: 0.2042
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1788 - val_loss: 0.1428
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1030 - val_loss: 0.0973
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0525 - val_loss: 0.0675
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0226 - val_loss: 0.0538
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0131 - val_loss: 0.0535
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0180 - val_loss: 0.0592
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0250 - val_loss: 0.0626
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0276 - val_loss: 0.0610
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0208 - val_loss: 0.0583
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0161 - val_loss: 0.0560
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0116 - val_loss: 0.0553
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0097 - val_loss: 0.0558
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0094 - val_loss: 0.0574
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0091 - val_loss: 0.0590
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0094 - val_loss: 0.0603
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0101 - val_loss: 0.0601
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0095 - val_loss: 0.0583
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0092 - val_loss: 0.0557
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0079 - val_loss: 0.0530
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0071 - val_loss: 0.0513
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0066 - val_loss: 0.0509
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0065 - val_loss: 0.0519
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0059 - val_loss: 0.0537
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0064 - val_loss: 0.0544
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0063 - val_loss: 0.0549
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0062 - val_loss: 0.0542
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0060 - val_loss: 0.0536
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0058 - val_loss: 0.0531
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0055 - val_loss: 0.0526
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0054 - val_loss: 0.0522
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0051 - val_loss: 0.0519
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0055 - val_loss: 0.0521
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0055 - val_loss: 0.0522
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0051 - val_loss: 0.0522
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0053 - val_loss: 0.0524
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0525
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - val_loss: 0.0522
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0048 - val_loss: 0.0519
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0047 - val_loss: 0.0514
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0046 - val_loss: 0.0511
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0044 - val_loss: 0.0509
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0047 - val_loss: 0.0510
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0044 - val_loss: 0.0511
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0043 - val_loss: 0.0509
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0044 - val_loss: 0.0504
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - val_loss: 0.0500
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042 - val_loss: 0.0496
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - val_loss: 0.0498
# Training GRU model for ST_RH...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_2 (GRU)                     │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2050 - val_loss: 0.1578
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0737 - val_loss: 0.0849
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0219 - val_loss: 0.0845
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0300 - val_loss: 0.0708
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0224 - val_loss: 0.0507
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0103 - val_loss: 0.0490
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0084 - val_loss: 0.0509
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088 - val_loss: 0.0484
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - val_loss: 0.0435
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0065 - val_loss: 0.0413
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0070 - val_loss: 0.0402
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049 - val_loss: 0.0391
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0056 - val_loss: 0.0377
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.0384
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0047 - val_loss: 0.0395
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0388
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042 - val_loss: 0.0366
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 0.0347
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.0331
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0336
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - val_loss: 0.0332
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0313
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0307
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0293
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.0289
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0282
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - val_loss: 0.0277
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0270
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0252
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021 - val_loss: 0.0248
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - val_loss: 0.0246
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0242
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0230
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0221
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0218
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0218
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0205
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0198
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0202
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0191
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0178
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0182
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0189
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0170
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0167
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0169
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 0.0166
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0164
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0153
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0157
# Training GRU model for ST_RK...
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 0.2938 - val_loss: 0.1983
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1955 - val_loss: 0.1206
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1176 - val_loss: 0.0623
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0683 - val_loss: 0.0229
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0299 - val_loss: 0.0041
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0183 - val_loss: 0.0045
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0129
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0335 - val_loss: 0.0153
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0343 - val_loss: 0.0106
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0301 - val_loss: 0.0049
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0196 - val_loss: 0.0021
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0154 - val_loss: 0.0023
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0142 - val_loss: 0.0040
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - val_loss: 0.0058
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0158 - val_loss: 0.0069
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0165 - val_loss: 0.0070
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0160 - val_loss: 0.0060
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0145 - val_loss: 0.0046
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0130 - val_loss: 0.0032
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0113 - val_loss: 0.0022
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0113 - val_loss: 0.0017
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0110 - val_loss: 0.0016
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0111 - val_loss: 0.0018
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0115 - val_loss: 0.0019
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0114 - val_loss: 0.0018
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0106 - val_loss: 0.0017
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0108 - val_loss: 0.0017
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0101 - val_loss: 0.0018
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0099 - val_loss: 0.0020
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0098 - val_loss: 0.0023
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0088 - val_loss: 0.0023
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0085 - val_loss: 0.0019
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0085 - val_loss: 0.0018
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0080 - val_loss: 0.0017
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0076 - val_loss: 0.0017
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0080 - val_loss: 0.0018
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0072 - val_loss: 0.0018
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0073 - val_loss: 0.0018
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0083 - val_loss: 0.0019
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0068 - val_loss: 0.0017
# Training GRU model for SW_RA...
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_6 (GRU)                     │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.2309 - val_loss: 0.2197
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1530 - val_loss: 0.1497
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0941 - val_loss: 0.0976
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0484 - val_loss: 0.0668
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0270 - val_loss: 0.0600
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0236 - val_loss: 0.0702
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0329 - val_loss: 0.0765
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0361 - val_loss: 0.0735
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0303 - val_loss: 0.0675
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0218 - val_loss: 0.0635
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0170 - val_loss: 0.0622
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0159 - val_loss: 0.0622
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0149 - val_loss: 0.0621
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0147 - val_loss: 0.0617
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0137 - val_loss: 0.0614
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0145 - val_loss: 0.0607
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0136 - val_loss: 0.0599
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0111 - val_loss: 0.0591
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0091 - val_loss: 0.0588
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0096 - val_loss: 0.0591
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0087 - val_loss: 0.0597
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0088 - val_loss: 0.0600
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0094 - val_loss: 0.0601
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0091 - val_loss: 0.0601
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0078 - val_loss: 0.0599
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0081 - val_loss: 0.0599
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0076 - val_loss: 0.0597
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0065 - val_loss: 0.0594
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0073 - val_loss: 0.0592
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0064 - val_loss: 0.0591
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0073 - val_loss: 0.0591
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0062 - val_loss: 0.0589
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0069 - val_loss: 0.0590
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0063 - val_loss: 0.0588
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0056 - val_loss: 0.0587
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0062 - val_loss: 0.0588
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0588
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0057 - val_loss: 0.0587
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0060 - val_loss: 0.0587
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0053 - val_loss: 0.0586
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0053 - val_loss: 0.0584
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0051 - val_loss: 0.0584
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0054 - val_loss: 0.0584
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0049 - val_loss: 0.0584
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0056 - val_loss: 0.0584
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0054 - val_loss: 0.0583
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0052 - val_loss: 0.0580
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - val_loss: 0.0579
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0057 - val_loss: 0.0578
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0043 - val_loss: 0.0578
# Training GRU model for SW_RH...
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_8 (GRU)                     │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_9 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.1592 - val_loss: 0.1778
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0596 - val_loss: 0.0895
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0327 - val_loss: 0.0712
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0270 - val_loss: 0.0642
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0214 - val_loss: 0.0583
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0113 - val_loss: 0.0614
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0118 - val_loss: 0.0619
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0099 - val_loss: 0.0558
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0095 - val_loss: 0.0453
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0082 - val_loss: 0.0396
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0076 - val_loss: 0.0383
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0070 - val_loss: 0.0377
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0067 - val_loss: 0.0383
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0058 - val_loss: 0.0385
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0057 - val_loss: 0.0364
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054 - val_loss: 0.0344
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0051 - val_loss: 0.0331
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0046 - val_loss: 0.0317
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - val_loss: 0.0311
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0297
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.0283
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - val_loss: 0.0276
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 0.0269
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - val_loss: 0.0255
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - val_loss: 0.0250
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - val_loss: 0.0248
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.0244
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.0235
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0225
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0220
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.0216
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0215
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - val_loss: 0.0210
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - val_loss: 0.0204
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.0198
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.0192
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0193
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024 - val_loss: 0.0189
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0180
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0178
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0175
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0170
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0165
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0161
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0162
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0154
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0151
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0150
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0145
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0143
# Training GRU model for SW_RK...
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_10 (GRU)                    │ (None, 10, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,904 (93.38 KB)
#  Trainable params: 23,904 (93.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - loss: 0.3284 - val_loss: 0.1883
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2268 - val_loss: 0.1415
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1311 - val_loss: 0.1059
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0782 - val_loss: 0.0857
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0520 - val_loss: 0.0775
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0503 - val_loss: 0.0751
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0543 - val_loss: 0.0671
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0522 - val_loss: 0.0555
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0432 - val_loss: 0.0443
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0359 - val_loss: 0.0354
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0281 - val_loss: 0.0293
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0266 - val_loss: 0.0256
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0249 - val_loss: 0.0241
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213 - val_loss: 0.0248
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0212 - val_loss: 0.0277
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0202 - val_loss: 0.0317
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0204 - val_loss: 0.0357
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0191 - val_loss: 0.0377
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0166 - val_loss: 0.0380
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0181 - val_loss: 0.0364
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0170 - val_loss: 0.0335
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0135 - val_loss: 0.0300
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0152 - val_loss: 0.0274
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0157 - val_loss: 0.0257
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0146 - val_loss: 0.0247
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0135 - val_loss: 0.0245
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0142 - val_loss: 0.0250
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0135 - val_loss: 0.0259
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0118 - val_loss: 0.0267
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0112 - val_loss: 0.0276
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0118 - val_loss: 0.0283
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0116 - val_loss: 0.0285
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0115 - val_loss: 0.0284
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0115 - val_loss: 0.0278
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0112 - val_loss: 0.0266
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0100 - val_loss: 0.0255
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0119 - val_loss: 0.0248
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0106 - val_loss: 0.0240
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0100 - val_loss: 0.0234
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0100 - val_loss: 0.0233
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0100 - val_loss: 0.0235
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0082 - val_loss: 0.0227
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0096 - val_loss: 0.0223
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0084 - val_loss: 0.0216
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0086 - val_loss: 0.0210
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0087 - val_loss: 0.0208
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0086 - val_loss: 0.0205
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0090 - val_loss: 0.0200
# {'ST_RA': <keras.src.callbacks.history.History object at 0x7b4ea821d6f0>, 'ST_RH': <keras.src.callbacks.history.History object at 0x7b4ea0132f80>, 'ST_RK': <keras.src.callbacks.history.History object at 0x7b4e6df4d2a0>, 'SW_RA': <keras.src.callbacks.history.History object at 0x7b4e40627970>, 'SW_RH': <keras.src.callbacks.history.History object at 0x7b4e41405db0>, 'SW_RK': <keras.src.callbacks.history.History object at 0x7b4e411e9390>}
# {'ST_RA': <Sequential name=sequential, built=True>, 'ST_RH': <Sequential name=sequential_1, built=True>, 'ST_RK': <Sequential name=sequential_2, built=True>, 'SW_RA': <Sequential name=sequential_3, built=True>, 'SW_RH': <Sequential name=sequential_4, built=True>, 'SW_RK': <Sequential name=sequential_5, built=True>}

# %%
print(histories)
print(models)
# Out:
# {'ST_RA': <keras.src.callbacks.history.History object at 0x7b4ea821d6f0>, 'ST_RH': <keras.src.callbacks.history.History object at 0x7b4ea0132f80>, 'ST_RK': <keras.src.callbacks.history.History object at 0x7b4e6df4d2a0>, 'SW_RA': <keras.src.callbacks.history.History object at 0x7b4e40627970>, 'SW_RH': <keras.src.callbacks.history.History object at 0x7b4e41405db0>, 'SW_RK': <keras.src.callbacks.history.History object at 0x7b4e411e9390>}
# {'ST_RA': <Sequential name=sequential, built=True>, 'ST_RH': <Sequential name=sequential_1, built=True>, 'ST_RK': <Sequential name=sequential_2, built=True>, 'SW_RA': <Sequential name=sequential_3, built=True>, 'SW_RH': <Sequential name=sequential_4, built=True>, 'SW_RK': <Sequential name=sequential_5, built=True>}

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler


# Evaluate models
def evaluate_model(model, X_test, y_test,scaler ,model_name):
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    print(f'{model_name} - Mean Squared Error: {mse}')
    print(f'{model_name} - Mean Absolute Error: {mae}')
    predictions_inverse = scaler.inverse_transform(predictions)
    print(X_test.shape)
    print(predictions.shape)
    print(predictions_inverse.shape)
    return predictions_inverse

# %%
# Plot results
def plot_predictions(y_test_inverse, predictions_inverse, feature_index, model_name, joint_name):
    plt.figure(figsize=(14, 7))
    
    # Plot true values vs predictions
    plt.plot(y_test_inverse[:, feature_index], label='True Values')
    plt.plot(predictions_inverse[:, feature_index], label=f'{model_name} Predictions')
    
    plt.xlabel('Time')
    plt.ylabel('X (m/s2)')
    plt.title(f'True Values vs {model_name} Predictions for X (m/s2) - {joint_name}')
    plt.legend()
    plt.show()

# %%
joint_data = {
    'ST_RA': (X_test_ST_RA, y_test_ST_RA, scaler_stance_RA),
    'ST_RH': (X_test_ST_RH, y_test_ST_RH, scaler_stance_RH),
    'ST_RK': (X_test_ST_RK, y_test_ST_RK, scaler_stance_RK),
    'SW_RA': (X_test_SW_RA, y_test_SW_RA, scaler_swing_RA),
    'SW_RH': (X_test_SW_RH, y_test_SW_RH, scaler_swing_RH),
    'SW_RK': (X_test_SW_RK, y_test_SW_RK, scaler_swing_RK)
}

for joint, (X_test, y_test, scaler) in joint_data.items():
    model = models[joint]
    
    if hasattr(scaler, 'min_'):
        predictions_inverse = evaluate_model(model, X_test, y_test, scaler, f'GRU for {joint}')
        
        y_test_inverse = scaler.inverse_transform(y_test)
        
        feature_index = 0
        
        plot_predictions(y_test_inverse, predictions_inverse, feature_index, 'GRU', joint)
    else:
        print(f"Scaler for {joint} has not been fitted.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# GRU for ST_RA - Mean Squared Error: 0.04688010823989426
# GRU for ST_RA - Mean Absolute Error: 0.17096951955892042
# (19, 10, 4)
# (19, 4)
# (19, 4)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# GRU for ST_RH - Mean Squared Error: 0.005338230624270336
# GRU for ST_RH - Mean Absolute Error: 0.061581847026816315
# (39, 10, 4)
# (39, 4)
# (39, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# GRU for ST_RK - Mean Squared Error: 0.011591021661357042
# GRU for ST_RK - Mean Absolute Error: 0.08728503906724525
# (19, 10, 4)
# (19, 4)
# (19, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# GRU for SW_RA - Mean Squared Error: 0.023322637121673966
# GRU for SW_RA - Mean Absolute Error: 0.1109808151799887
# (19, 10, 4)
# (19, 4)
# (19, 4)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# GRU for SW_RH - Mean Squared Error: 0.005132475212961155
# GRU for SW_RH - Mean Absolute Error: 0.05687996533454236
# (39, 10, 4)
# (39, 4)
# (39, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# GRU for SW_RK - Mean Squared Error: 0.03855877079384293
# GRU for SW_RK - Mean Absolute Error: 0.1783372682692659
# (18, 10, 4)
# (18, 4)
# (18, 4)

# %%
import matplotlib.pyplot as plt

def plot_joint_predictions(joint, y_test_inverse_stance, predictions_inverse_stance, y_test_inverse_swing, predictions_inverse_swing):
    fig, axes = plt.subplots(3, 2, figsize=(12, 12))

    axes_labels = ['X (m/s²)', 'Y (m/s²)', 'Z (m/s²)']
    
    for i in range(3):  # For X, Y, and Z axis
        axes[i, 0].plot(y_test_inverse_stance[:, i], label='True', color='blue')
        axes[i, 0].plot(predictions_inverse_stance[:, i], label='Predicted', color='orange')
        axes[i, 0].set_title(f'{joint} Stance - {axes_labels[i]}')
        axes[i, 0].legend()
        
        axes[i, 1].plot(y_test_inverse_swing[:, i], label='True', color='blue')
        axes[i, 1].plot(predictions_inverse_swing[:, i], label='Predicted', color='orange')
        axes[i, 1].set_title(f'{joint} Swing - {axes_labels[i]}')
        axes[i, 1].legend()

    plt.tight_layout()
    plt.show()

y_test_inverse_stance_RK = scaler_stance_RK.inverse_transform(y_test_ST_RK)
y_test_inverse_swing_RK = scaler_swing_RK.inverse_transform(y_test_SW_RK)

predictions_inverse_stance_RK = evaluate_model(models['ST_RK'], X_test_ST_RK, y_test_ST_RK, scaler_stance_RK, 'GRU for ST_RK')
predictions_inverse_swing_RK = evaluate_model(models['SW_RK'], X_test_SW_RK, y_test_SW_RK, scaler_swing_RK, 'GRU for SW_RK')
plot_joint_predictions('RK', y_test_inverse_stance_RK, predictions_inverse_stance_RK, y_test_inverse_swing_RK, predictions_inverse_swing_RK)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# GRU for ST_RK - Mean Squared Error: 0.011591021661357042
# GRU for ST_RK - Mean Absolute Error: 0.08728503906724525
# (19, 10, 4)
# (19, 4)
# (19, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# GRU for SW_RK - Mean Squared Error: 0.03855877079384293
# GRU for SW_RK - Mean Absolute Error: 0.1783372682692659
# (18, 10, 4)
# (18, 4)
# (18, 4)

# %%
y_test_inverse_stance_RA = scaler_stance_RA.inverse_transform(y_test_ST_RA)
y_test_inverse_swing_RA = scaler_swing_RA.inverse_transform(y_test_SW_RA)

predictions_inverse_stance_RA = evaluate_model(models['ST_RA'], X_test_ST_RA, y_test_ST_RA, scaler_stance_RA, 'GRU for ST_RA')
predictions_inverse_swing_RA = evaluate_model(models['SW_RA'], X_test_SW_RA, y_test_SW_RA, scaler_swing_RA, 'GRU for SW_RA')

plot_joint_predictions('RA', y_test_inverse_stance_RA, predictions_inverse_stance_RA, y_test_inverse_swing_RA, predictions_inverse_swing_RA)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GRU for ST_RA - Mean Squared Error: 0.04688010823989426
# GRU for ST_RA - Mean Absolute Error: 0.17096951955892042
# (19, 10, 4)
# (19, 4)
# (19, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# GRU for SW_RA - Mean Squared Error: 0.023322637121673966
# GRU for SW_RA - Mean Absolute Error: 0.1109808151799887
# (19, 10, 4)
# (19, 4)
# (19, 4)

# %%
y_test_inverse_stance_RH = scaler_stance_RH.inverse_transform(y_test_ST_RH)
y_test_inverse_swing_RH = scaler_swing_RH.inverse_transform(y_test_SW_RH)

predictions_inverse_stance_RH = evaluate_model(models['ST_RH'], X_test_ST_RH, y_test_ST_RH, scaler_stance_RH, 'GRU for ST_RH')
predictions_inverse_swing_RH = evaluate_model(models['SW_RH'], X_test_SW_RH, y_test_SW_RH, scaler_swing_RH, 'GRU for SW_RH')

plot_joint_predictions('RH', y_test_inverse_stance_RH, predictions_inverse_stance_RH, y_test_inverse_swing_RH, predictions_inverse_swing_RH)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# GRU for ST_RH - Mean Squared Error: 0.005338230624270336
# GRU for ST_RH - Mean Absolute Error: 0.061581847026816315
# (39, 10, 4)
# (39, 4)
# (39, 4)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# GRU for SW_RH - Mean Squared Error: 0.005132475212961155
# GRU for SW_RH - Mean Absolute Error: 0.05687996533454236
# (39, 10, 4)
# (39, 4)
# (39, 4)
